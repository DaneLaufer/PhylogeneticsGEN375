# %%
import tester
import dataframe_image as dfi
import pandas as pd
import matplotlib

# %%
tester.genDFforGene('nhaR')
# Out:
# <style type="text/css">
# #T_40901_row0_col0, #T_40901_row1_col1, #T_40901_row2_col2, #T_40901_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_40901_row0_col1 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_40901_row0_col2 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_40901_row0_col3, #T_40901_row3_col0, #T_40901_row3_col1, #T_40901_row3_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_40901_row1_col0 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_40901_row1_col2, #T_40901_row2_col1 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_40901_row1_col3 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_40901_row2_col0 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_40901_row2_col3 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_40901">
#   <caption>nhaR - 906 nucleotides</caption>
#   <thead>
#     <tr>
# ...

# %%
tester.genDFforGene('yaaA')
# Out:
# <style type="text/css">
# #T_b49e6_row0_col0, #T_b49e6_row0_col3, #T_b49e6_row1_col1, #T_b49e6_row2_col2, #T_b49e6_row3_col0, #T_b49e6_row3_col3, #T_b49e6_row4_col4, #T_b49e6_row5_col5 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_b49e6_row0_col1, #T_b49e6_row3_col1 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_b49e6_row0_col2, #T_b49e6_row3_col2 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_b49e6_row0_col4, #T_b49e6_row3_col4 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_b49e6_row0_col5, #T_b49e6_row3_col5 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_b49e6_row1_col0, #T_b49e6_row1_col3 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_b49e6_row1_col2 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_b49e6_row1_col4 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_b49e6_row1_col5 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# ...

# %%
tester.genDFforGene('nhaA')
# Out:
# <style type="text/css">
# #T_827d7_row0_col0, #T_827d7_row1_col1, #T_827d7_row2_col2, #T_827d7_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_827d7_row0_col1 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_827d7_row0_col2 {
#   background-color: #1e86bb;
#   color: #f1f1f1;
# }
# #T_827d7_row0_col3 {
#   background-color: #21318d;
#   color: #f1f1f1;
# }
# #T_827d7_row1_col0 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_827d7_row1_col2 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_827d7_row1_col3 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_827d7_row2_col0 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_827d7_row2_col1 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_827d7_row2_col3, #T_827d7_row3_col0, #T_827d7_row3_col1, #T_827d7_row3_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_827d7">
# ...

# %%
tester.genDFforGene('thrA')
# Out:
# <style type="text/css">
# #T_83b0c_row0_col0, #T_83b0c_row1_col1, #T_83b0c_row2_col2, #T_83b0c_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_83b0c_row0_col1 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_83b0c_row0_col2 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_83b0c_row0_col3 {
#   background-color: #2260a9;
#   color: #f1f1f1;
# }
# #T_83b0c_row1_col0, #T_83b0c_row1_col2, #T_83b0c_row1_col3, #T_83b0c_row2_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_83b0c_row2_col0 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_83b0c_row2_col3, #T_83b0c_row3_col0 {
#   background-color: #203089;
#   color: #f1f1f1;
# }
# #T_83b0c_row3_col1 {
#   background-color: #192b7c;
#   color: #f1f1f1;
# }
# #T_83b0c_row3_col2 {
#   background-color: #24439b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83b0c">
#   <caption>thrA - 2463 nucleotides</caption>
#   <thead>
#     <tr>
# ...

# %%
tester.genDFforGene('thrC')
# Out:
# <style type="text/css">
# #T_6f955_row0_col0, #T_6f955_row1_col1, #T_6f955_row2_col2, #T_6f955_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_6f955_row0_col1 {
#   background-color: #1d8dbe;
#   color: #f1f1f1;
# }
# #T_6f955_row0_col2 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_6f955_row0_col3 {
#   background-color: #182a7a;
#   color: #f1f1f1;
# }
# #T_6f955_row1_col0 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_6f955_row1_col2, #T_6f955_row1_col3, #T_6f955_row2_col0, #T_6f955_row2_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_6f955_row2_col3 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_6f955_row3_col0 {
#   background-color: #21308b;
#   color: #f1f1f1;
# }
# #T_6f955_row3_col1 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_6f955_row3_col2 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# </style>
# <table id="T_6f955">
# ...

# %%
tester.genDFforGene('thrB')
# Out:
# <style type="text/css">
# #T_8cd99_row0_col0, #T_8cd99_row1_col1, #T_8cd99_row2_col2, #T_8cd99_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_8cd99_row0_col1, #T_8cd99_row2_col1 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_8cd99_row0_col2, #T_8cd99_row2_col0 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_8cd99_row0_col3, #T_8cd99_row2_col3 {
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_8cd99_row1_col0, #T_8cd99_row1_col2, #T_8cd99_row1_col3, #T_8cd99_row3_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_8cd99_row3_col0, #T_8cd99_row3_col2 {
#   background-color: #24419a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8cd99">
#   <caption>thrB - 933 nucleotides</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cd99_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_8cd99_level0_col1" class="col_heading level0 col1" >3</th>
# ...

# %%
tester.genDFforGene('satP')
# Out:
# <style type="text/css">
# #T_af349_row0_col0, #T_af349_row0_col3, #T_af349_row1_col1, #T_af349_row1_col2, #T_af349_row2_col1, #T_af349_row2_col2, #T_af349_row3_col0, #T_af349_row3_col3, #T_af349_row4_col4, #T_af349_row5_col5 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_af349_row0_col1, #T_af349_row0_col2, #T_af349_row1_col0, #T_af349_row1_col3, #T_af349_row2_col0, #T_af349_row2_col3, #T_af349_row3_col1, #T_af349_row3_col2 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_af349_row0_col4, #T_af349_row1_col4, #T_af349_row2_col4, #T_af349_row3_col4, #T_af349_row4_col0, #T_af349_row4_col1, #T_af349_row4_col2, #T_af349_row4_col3, #T_af349_row4_col5 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_af349_row0_col5, #T_af349_row3_col5 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_af349_row1_col5, #T_af349_row2_col5 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_af349_row5_col0, #T_af349_row5_col3 {
# ...

# %%
tester.genDFforGene('dnaJ')
# Out:
# <style type="text/css">
# #T_ca6cc_row0_col0, #T_ca6cc_row1_col1, #T_ca6cc_row2_col2, #T_ca6cc_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_ca6cc_row0_col1, #T_ca6cc_row3_col1 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# #T_ca6cc_row0_col2 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_ca6cc_row0_col3 {
#   background-color: #21318d;
#   color: #f1f1f1;
# }
# #T_ca6cc_row1_col0 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_ca6cc_row1_col2 {
#   background-color: #182a7a;
#   color: #f1f1f1;
# }
# #T_ca6cc_row1_col3 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_ca6cc_row2_col0 {
#   background-color: #1b2c80;
#   color: #f1f1f1;
# }
# #T_ca6cc_row2_col1, #T_ca6cc_row2_col3, #T_ca6cc_row3_col0, #T_ca6cc_row3_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ca6cc">
#   <caption>dnaJ - 1131 nucleotides</caption>
#   <thead>
#     <tr>
# ...

# %%
tester.genDFforGene('ribF')
# Out:
# <style type="text/css">
# #T_09cfd_row0_col0, #T_09cfd_row1_col1, #T_09cfd_row2_col2, #T_09cfd_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_09cfd_row0_col1 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_09cfd_row0_col2 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_09cfd_row0_col3 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_09cfd_row1_col0 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_09cfd_row1_col2 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_09cfd_row1_col3, #T_09cfd_row3_col0, #T_09cfd_row3_col1, #T_09cfd_row3_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_09cfd_row2_col0 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_09cfd_row2_col1 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_09cfd_row2_col3 {
#   background-color: #2355a4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09cfd">
# ...

# %%
tester.genDFforGene('mog')
# Out:
# <style type="text/css">
# #T_c30df_row0_col0, #T_c30df_row1_col1, #T_c30df_row2_col2, #T_c30df_row3_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_c30df_row0_col1 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_c30df_row0_col2, #T_c30df_row1_col2, #T_c30df_row1_col3, #T_c30df_row2_col0, #T_c30df_row3_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_c30df_row0_col3 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_c30df_row1_col0 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_c30df_row2_col1 {
#   background-color: #21318d;
#   color: #f1f1f1;
# }
# #T_c30df_row2_col3 {
#   background-color: #2354a3;
#   color: #f1f1f1;
# }
# #T_c30df_row3_col0 {
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_c30df_row3_col2 {
#   background-color: #243392;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c30df">
#   <caption>mog - 588 nucleotides</caption>
#   <thead>
#     <tr>
# ...
